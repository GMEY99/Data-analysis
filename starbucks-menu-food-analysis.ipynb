# %%
import numpy as np   
import matplotlib.pyplot as plt  
import pandas as pd  
import seaborn as sns

# %%
import pandas as pd
import chardet

# Detect the encoding
with open(r'C:\Users\gmeyg\Downloads\Compressed\starbucs\starbucks-menu-nutrition-food.csv', 'rb') as f:
    result = chardet.detect(f.read())

# Use the detected encoding
df = pd.read_csv(r'C:\Users\gmeyg\Downloads\Compressed\starbucs\starbucks-menu-nutrition-food.csv', encoding=result['encoding'])

# %%
df
# Out:
#                              Unnamed: 0   Calories   Fat (g)   Carb. (g)  \
# 0                          Chonga Bagel        300       5.0          50
# 1                          8-Grain Roll        380       6.0          70
# 2                      Almond Croissant        410      22.0          45
# 3                         Apple Fritter        460      23.0          56
# 4                      Banana Nut Bread        420      22.0          52
# ..                                  ...        ...       ...         ...
# 108  Justin's Chocolate Hazelnut Butter        180      14.0          12
# 109      Justin's Classic Almond Butter        190      18.0           6
# 110                Lemon Chiffon Yogurt        340      13.0          38
# 111            Organic Avocado (Spread)         90       8.0           5
# 112                Seasonal Fruit Blend         90       0.0          24
#
#       Fiber (g)   Protein (g)
# 0             3            12
# ...

# %%
df=df.rename(columns={'Unnamed: 0':'menu'})
df=df.rename(columns={' Calories':'Calories'})
df=df.rename(columns={' Fat (g)':'Fat(g)'})
df=df.rename(columns={' Carb. (g)':'Carb(g)'})
df=df.rename(columns={' Fiber (g)':'Fiber(g)'})
df=df.rename(columns={' Protein (g)':'Protein(g)'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   menu        113 non-null    object
#  1   Calories    113 non-null    int64
#  2   Fat(g)      113 non-null    float64
#  3   Carb(g)     113 non-null    int64
#  4   Fiber(g)    113 non-null    int64
#  5   Protein(g)  113 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 5.4+ KB

# %%
df.describe()
# Out:
#          Calories      Fat(g)     Carb(g)    Fiber(g)  Protein(g)
# count  113.000000  113.000000  113.000000  113.000000  113.000000
# mean   356.637168   16.353982   41.486726    2.849558   11.469027
# std    127.710685    8.297397   15.796764    2.888466    8.463230
# min     90.000000    0.000000    5.000000    0.000000    1.000000
# 25%    280.000000    9.000000   31.000000    1.000000    5.000000
# 50%    360.000000   17.000000   42.000000    2.000000    8.000000
# 75%    450.000000   23.000000   53.000000    3.000000   19.000000
# max    650.000000   37.000000   80.000000   21.000000   34.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#             Calories    Fat(g)   Carb(g)  Fiber(g)  Protein(g)
# Calories    1.000000  0.828929  0.708496  0.471079    0.618962
# Fat(g)      0.828929  1.000000  0.281132  0.276059    0.423364
# Carb(g)     0.708496  0.281132  1.000000  0.407655    0.204375
# Fiber(g)    0.471079  0.276059  0.407655  1.000000    0.472246
# Protein(g)  0.618962  0.423364  0.204375  0.472246    1.000000

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,15))
sns.boxplot(data=df)
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(x='Fiber(g)', data=df)
plt.show()

# %%
df=df[df['Fiber(g)']<=6.5]

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(x='Fiber(g)', data=df)
plt.show()

# %%
df.describe()
# Out:
#          Calories      Fat(g)     Carb(g)    Fiber(g)  Protein(g)
# count  102.000000  102.000000  102.000000  102.000000  102.000000
# mean   342.156863   15.872549   39.480392    2.137255   10.764706
# std    120.901133    7.865417   14.691366    1.522369    8.375089
# min     90.000000    0.000000    5.000000    0.000000    1.000000
# 25%    255.000000    9.000000   30.000000    1.000000    4.250000
# 50%    360.000000   17.000000   41.500000    2.000000    7.000000
# 75%    437.500000   22.000000   49.750000    3.000000   18.000000
# max    600.000000   32.000000   68.000000    6.000000   34.000000

# %%
df
# Out:
#                                        menu  Calories  Fat(g)  Carb(g)  \
# 0                              Chonga Bagel       300     5.0       50
# 2                          Almond Croissant       410    22.0       45
# 3                             Apple Fritter       460    23.0       56
# 4                          Banana Nut Bread       420    22.0       52
# 5    Blueberry Muffin with Yogurt and Honey       380    16.0       53
# ..                                      ...       ...     ...      ...
# 108      Justin's Chocolate Hazelnut Butter       180    14.0       12
# 109          Justin's Classic Almond Butter       190    18.0        6
# 110                    Lemon Chiffon Yogurt       340    13.0       38
# 111                Organic Avocado (Spread)        90     8.0        5
# 112                    Seasonal Fruit Blend        90     0.0       24
#
#      Fiber(g)  Protein(g)
# 0           3          12
# 2           3          10
# 3           2           7
# ...

# %%
df.sort_values('Calories',ascending=False )
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                                              menu  Calories  Fat(g)  Carb(g)  \
# 0          Roasted Turkey & Dill Havarti Sandwich       600    32.0       47
# 1                             Turkey Pesto Panini       560    23.0       55
# 2                 Seared Steak & Cheddar Sandwich       530    29.0       44
# 3                                PB&J Protein Box       520    26.0       53
# 4    Chicken Artichoke on Ancient Grain Flatbread       510    27.0       37
# ..                                            ...       ...     ...      ...
# 97                      Petite Vanilla Bean Scone       120     4.5       18
# 98   Everybody's Favorite - Bantam Bagel (2 Pack)       100     3.5       14
# 99                      Frappuccino® Cookie Straw        90     3.0       14
# 100                      Organic Avocado (Spread)        90     8.0        5
# 101                          Seasonal Fruit Blend        90     0.0       24
#
#      Fiber(g)  Protein(g)
# ...

# %%
df.to_csv(r'C:\Users\gmeyg\Downloads\Compressed\starbucs\starbucks-menu-food-analysis.csv', index=False)
